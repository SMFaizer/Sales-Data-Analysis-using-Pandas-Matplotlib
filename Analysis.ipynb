# %% [markdown]
# Import necessary Libraries:

# %%
import pandas as pd
import os

# %% [markdown]
# Merge the 12 individual files into a single csv file

# %%
df=pd.read_csv(r"C:\Users\USER\Documents\GitHub\New folder\Sales Data Analysis Using Python Pandas\SalesAnalysis\Sales_Data\Sales_April_2019.csv")

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df.tail()
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215

# %%
folder_path=r"C:\Users\USER\Documents\GitHub\New folder\Sales Data Analysis Using Python Pandas\SalesAnalysis\Sales_Data"
files=[file for file in os.listdir(folder_path)]

# %%
for file in files:
    print(file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
all_months_data=pd.DataFrame()
for file in files:
    df=pd.read_csv(os.path.join(folder_path,file))
    all_months_data=pd.concat([all_months_data,df])
all_months_data.to_csv("all_data_csv",index=False)

# %% [markdown]
# Read in Updated Dataframe:

# %%
all_data=pd.read_csv("all_data_csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Clean up The data:

# %% [markdown]
# Eliminate Empty rows:

# %%
all_data=all_data.dropna(how="all")

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# Reset index after Dropping:

# %%
all_data=all_data.reset_index(drop="True")

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# Find 'Or' and delete it:

# %%
all_data=all_data[all_data['Order Date'].str[0:2]!='Or']
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# Make Column Numeric if there are any string data present in any column:

# %%
all_data['Quantity Ordered']=pd.to_numeric(all_data['Quantity Ordered']) # int type
all_data['Price Each']=pd.to_numeric(all_data['Price Each']) # float type
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ### Augment Data for Additional Column:

# %% [markdown]
# ### 1) Add month Column:

# %%
all_data['Months']=all_data['Order Date'].str[0:2]
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Months
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     04
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     04
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     04

# %%
all_data['Months']=all_data['Months'].astype('int32')
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Months
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4

# %%
all_data.tail()
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 186300   259353  AAA Batteries (4-pack)                 3        2.99
# 186301   259354                  iPhone                 1      700.00
# 186302   259355                  iPhone                 1      700.00
# 186303   259356  34in Ultrawide Monitor                 1      379.99
# 186304   259357    USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Months
# 186300  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001       9
# 186301  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016       9
# 186302  09/23/19 07:39     220 12th St, San Francisco, CA 94016       9
# 186303  09/19/19 17:30   511 Forest St, San Francisco, CA 94016       9
# 186304  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016       9

# %% [markdown]
# 2) Add New column for sales:

# %%
all_data['Sales']=all_data['Quantity Ordered']*all_data['Price Each']
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Months   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4   11.99

# %% [markdown]
# 3. Add a city Column:

# %%
#use .apply() formula:
def getcity(address):
    return address.split(',')[1]
def getstate(address):
    return address.split(',')[2].split(' ')[1]

all_data['City']=all_data['Purchase Address'].apply(lambda x:f"{getcity(x)} {getstate(x)}")

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Months   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4   11.99
#
#               City
# 0        Dallas TX
# 1        Boston MA
# 2   Los Angeles CA
# 3   Los Angeles CA
# ...

# %% [markdown]
# ### Question 1: What was the best month for sales? How much was earned that month?

# %%
all_data.groupby('Months').sum()
# Out:
#                                                  Order ID  \
# Months
# 1       2971502978172978172979692983442990492991253003...
# 2       1505021505031505041505051505061505071505081505...
# 3       1505331505411508121517491520361532841535441538...
# 4       1765581765591765601765601765611765621765631765...
# 5       1769781775511777781777781790761790761791341800...
# 6       2099212099222099232099242099252099262099272099...
# 7       2229102229112229122229132229142229152229162229...
# 8       2366702366712366722366732366742366752366762366...
# 9       2388342392852406362410542423432428652436672449...
# 10      2593582593592593602593612593622593632593642593...
# 11      2787972787982787992788002788012788022788032788...
# 12      2956652956662956672956682956692956702956712956...
#
#                                                   Product  Quantity Ordered  \
# Months
# 1       Lightning Charging CableiPhoneLightning Chargi...             10903
# ...

# %%
import matplotlib.pyplot as plt

# %%
results=all_data.groupby('Months').sum()

# %%
months=range(1,13)
plt.bar(months,results['Sales'])
plt.xticks(months)
plt.xlabel('Months number')
plt.ylabel('Sales in USD($)')
plt.title("Sales in USD for each months")
plt.show()

# %% [markdown]
# ### Question 2) Which city has the highest Sales:

# %%
sales_city=all_data.groupby('City').sum()
sales_city.head(10)
# Out:
#                                                            Order ID  \
# City
# Atlanta GA        1765641765711765821765891766231766271766341766...
# Austin TX         1765911766091766741766771766861767011767051767...
# Boston MA         1765591765661765781765811765851765851766001766...
# Dallas TX         1765581765691765701765771765961766021766101766...
# Los Angeles CA    1765601765601765611765671765741765741765761765...
# New York City NY  1765721765751765791765901765991766131766371766...
# Portland ME       1767731768791769091770721772301772331772991773...
# Portland OR       1765831765931766171766421766461766481766621767...
# San Francisco CA  1765621765651765731765841765861765861765941765...
# Seattle WA        1765631765681765881766121766241766541766631766...
#
#                                                             Product  \
# City
# Atlanta GA        USB-C Charging CableLightning Charging CableBo...
# ...

# %%
cities=[city for city, df in all_data.groupby('City')]
plt.plot(cities,sales_city['Sales'])
plt.xlabel('Cities:')
plt.ylabel('Sales in USD($)')
plt.xticks(cities,rotation='vertical',size='8')
plt.title("Sales in USD in Different Cities")
plt.show()

# %% [markdown]
# ### Question 3) What time should we display advertisements for maximize the likelihood of sales products:

# %%
all_data['Order Date']=pd.to_datetime(all_data['Order Date'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25768\2323392424.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   all_data['Order Date']=pd.to_datetime(all_data['Order Date'])

# %%
all_data['Hours']=all_data['Order Date'].dt.hour
all_data['Minutes']=all_data['Order Date'].dt.minute
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Months   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001       4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215       4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001       4   11.99
#
#               City  Hours  Minutes
# 0        Dallas TX      8       46
# ...

# %%
hours=[hour for hour,df in all_data.groupby('Hours')]
result=all_data.groupby('Hours').count()
result.head()
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hours
# 0          3910     3910              3910        3910        3910
# 1          2350     2350              2350        2350        2350
# 2          1243     1243              1243        1243        1243
# 3           831      831               831         831         831
# 4           854      854               854         854         854
#
#        Purchase Address  Months  Sales  City  Minutes
# Hours
# 0                  3910    3910   3910  3910     3910
# 1                  2350    2350   2350  2350     2350
# 2                  1243    1243   1243  1243     1243
# 3                   831     831    831   831      831
# 4                   854     854    854   854      854

# %%
plt.plot(hours,result)
plt.xlabel('Hours')
plt.ylabel('Sales in USD($)')
plt.xticks(hours)
plt.title("Sales in USD in Different Hours")
plt.grid()
plt.show()

# %% [markdown]
# ### Question 4) What products are most ofter sold together?

# %%
df=all_data[all_data['Order ID'].duplicated(keep=False)]
df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25768\2805960672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 17   176574                Google Phone                 1      600.00
# 18   176574        USB-C Charging Cable                 1       11.95
# 29   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address  Months   Sales  \
# ...

# %%
df=df[['Order ID', 'Grouped']].drop_duplicates()
df.head(20)
# Out:
#     Order ID                                            Grouped
# 2     176560                      Google Phone,Wired Headphones
# 17    176574                  Google Phone,USB-C Charging Cable
# 29    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 31    176586                AAA Batteries (4-pack),Google Phone
# 118   176672      Lightning Charging Cable,USB-C Charging Cable
# 128   176681           Apple Airpods Headphones,ThinkPad Laptop
# 137   176689  Bose SoundSport Headphones,AAA Batteries (4-pack)
# 188   176739                34in Ultrawide Monitor,Google Phone
# 224   176774      Lightning Charging Cable,USB-C Charging Cable
# 232   176781                    iPhone,Lightning Charging Cable
# 249   176797  Google Phone,Bose SoundSport Headphones,Wired ...
# 259   176805                  Google Phone,USB-C Charging Cable
# 263   176808                      Google Phone,Wired Headphones
# 269   176813                      Google Phone,Wired Headphones
# ...

# %%
from itertools import combinations
from collections import Counter

# %%
count=Counter()
for row in df['Grouped']:
    row_list=row.split(',')
    count.update(Counter(combinations(row_list,2)))


for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### Question 5) What product sold the most? what do you think it sold the most?

# %%
product_group=all_data.groupby('Product')
product_group.sum(numeric_only=True)
# Out:
#                             Quantity Ordered  Price Each  Months       Sales  \
# Product
# 20in Monitor                            4129   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# 27in FHD Monitor                        7550  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                  27635    79015.68  145558   106118.40
# AAA Batteries (4-pack)                 31017    61716.59  146370    92740.83
# Apple Airpods Headphones               15661  2332350.00  109477  2349150.00
# Bose SoundSport Headphones             13457  1332366.75   94113  1345565.43
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# LG Dryer                                 646   387600.00    4383   387600.00
# ...

# %%
product_group=all_data.groupby('Product')
Quantity_ordered=product_group.sum(numeric_only=True)['Quantity Ordered']
products=[product for product, df in product_group]
plt.bar(products,Quantity_ordered)
plt.xlabel('Products')
plt.title('Quantity Ordered for each products')
plt.ylabel('Quantity Ordered')
plt.xticks(products,rotation='vertical',size=8)
plt.show()

# %%
# Convert 'Price Each' to numeric (force errors to NaN)
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'], errors='coerce')

# Drop rows where 'Price Each' is NaN (optional, but safe)
all_data = all_data.dropna(subset=['Price Each'])

# Now group and get the mean
prices = all_data.groupby('Product')['Price Each'].mean()
print(prices)
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
fig,ax1=plt.subplots()
ax2=ax1.twinx()
ax1.bar(products,Quantity_ordered,color='g')
ax2.plot(products,prices,'b-')
ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered',color='b')
ax2.set_ylabel('Prices($)',color='b')
ax1.set_xticklabels(products,rotation='vertical',size=8)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25768\2658216565.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(products,rotation='vertical',size=8)
